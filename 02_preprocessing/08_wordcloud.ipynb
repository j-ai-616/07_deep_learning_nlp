# %% [markdown]
# ## Word Cloud
#
# Word Cloud는 텍스트 데이터를 시각화하여 각 단어의 빈도(혹은 중요도)에 따라 단어의 크기를 다르게 표현하는 기법이다.
#
# ### 1. 텍스트 전처리
#
# 워드 클라우드는 입력된 텍스트 데이터를 분석하여 각 단어의 빈도를 계산한다.
#
# 벡터화 방법으로 가장 많이 사용되는 것은 Bag-of-Words 모델이며, 각 단어의 빈도를 기반으로 단어 크기를 결정한다. TF-IDF 역시 자주 사용되며, 특히 중요도가 강조되어야 하는 경우에 적합하다.
#
# * 소문자 변환: 단어의 일관성을 유지하기 위해 모든 단어를 소문자로 변환한다.
# * 불필요한 문자 제거: 특수문자, 숫자 등 분석에 필요하지 않은 문자를 제거한다.
# * 불용어(stop words) 제거: "and", "the", "is"와 같은 자주 등장하지만 의미가 없는 단어를 제거한다.
#
# ### 2. 단어 빈도 계산
#
# 전처리된 텍스트에서 각 단어의 빈도를 계산한다. 여기서는 일반적으로 단어의 출현 횟수를 세어 각 단어의 빈도를 결정한다.
#
# ### 3. 단어의 크기 결정
#
# 각 단어의 빈도에 따라 단어의 크기를 결정한다. 빈도가 높을수록 더 큰 글자로 표시되며, 빈도가 낮을수록 작은 글자로 표시된다. 이때 크기는 비례적으로 결정되며, 사용자 지정 옵션을 통해 최대/최소 크기 등을 조정할 수 있다.
#
# ### 4. 단어 배치
#
# 단어 배치는 일반적으로 가중치에 따라 특정 영역 내에서 임의로 배치된다. `WordCloud` 라이브러리는 배치 시 다음을 고려한다:
#
# * 충돌 방지: 단어가 서로 겹치지 않도록 배치 알고리즘을 사용한다.
# * 형태 유지: 특정 모양(예: 원, 이미지 형태 등)을 유지하면서 단어를 배치할 수 있다.
#
# ### 5. 시각화
#
# 배치된 단어들을 바탕으로 최종 이미지가 생성된다.
#
# 이 과정에서 사용자는 배경 색상, 단어 색상 팔레트, 글꼴 등을 조정할 수 있다.
#
# `WordCloud` 라이브러리는 `matplotlib`과 같은 시각화 라이브러리와 함께 사용되어 이미지를 화면에 출력한다.
#
# ## 작동 원리를 정리
#
# 1. 텍스트 데이터를 전처리하고 단어의 빈도를 계산한다.
# 2. 빈도에 비례하여 단어 크기를 결정한다.
# 3. 단어를 배치 알고리즘에 따라 충돌을 피하면서 이미지 안에 배치한다.
# 4. 사용자 지정 옵션에 따라 배경색, 단어 색상, 모양 등을 조정한다.

# %% [markdown]
# ## 데이터 전처리

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

spam_df = pd.read_csv('ko_sms_spam.csv')
spam_df.head()
# Out:
#       SEQ                                                 CN
# 0  842298  [Web발신]ifg@(광고)[한음대리점 율량점] 류태자 단골고객님ifg@ifg@마지...
# 1  842299  [Web발신]ifg@(광고)[전자랜드중동점]ifg@최은순 고객님!ifg@전자랜드 *...
# 2  842300  제목 : (광고)현대미아점 통합ifg@▶*O,OOO원할인권◀도착ifg@현대미아 설화...
# 3  842301  [Web발신]ifg@(광고) 신세계면세점 명동점ifg@ifg@본 문자 수신 고객님께...
# 4  842302  [Web발신]ifg@(광고) 롯데마트 소중한 집사의 통장을 지켜라! 멍이도 냥이도 ...

# %%
# 말뭉치 생성
corpus = '\n\n'.join(spam_df['CN'].iloc[:300])      # 앞에 있는 300개 메세지만 사용
corpus
# Out:
# "[Web발신]ifg@(광고)[한음대리점 율량점] 류태자 단골고객님ifg@ifg@마지막 최대할인입니다!!!!!!!ifg@SKT SKT SKT 기기변경 기기변경 ifg@ifg@▶▶▶▶▶Z플립* ***G◀◀◀◀◀ifg@☞☞☞☞공시지원금 기준☜☜☜☜ifg@ifg@기기값 : *,***,***원ifg@ifg@공시지원금 : -***,***원ifg@매장추가지원금 : -***,***원 ifg@ifg@★★★구매금액 : **,***원★★★ifg@ifg@***G 대용량 저장공간이라 오래오래 사용하실 수 있습니다!!!!ifg@극소량으로 조기종료가능성 있습니다ifg@ifg@▶ 단골이라서 더 드림 혜택 자세히 보기(SKT 공식 대리점 홈페이지로 연결) ifg@http://dangol.t-mms.kr/dt.do?m=*********&u=tworldfriends.co.kr/D*********ifg@ifg@(무료ARS)수신거부 및 단골해지 : ifg@***-***-****\n\n[Web발신]ifg@(광고)[전자랜드중동점]ifg@최은순 고객님!ifg@전자랜드 *월 전국동시세일! ifg@기간 : *.**(토)-*.**(월)ifg@ifg@가전제품 당일배달은 안될까?ifg@▼ 전자랜드 배민스토어 바로배달! ▼ifg@https://s.baemin.com/aiw.y*xfpifg@ifg@▶ 입주혼수가전 견적 꼭한번 들러야 할 곳ifg@▶ 에어컨 추천 전문가 *IN* 에어컨 ***만ifg@▶ 냉장고 건조기 TV 등 **개 품목 전국동시세일ifg@▶ 선풍기 **인치 **,***원 / 건조기 삼성 **KG **만           ifg@▶ 냉장고 ***L ***,*** / LG ***L ***만ifg@▶ TV LG **인치 LG ***만 / 삼성 **인치 ***만ifg@▶ 아이폰**미니, 갤럭시A** 학생폰 추천 ***원 / S** **만원대 ifg@ifg@▼ 모바일 행사내용 보기 ▼ifg@http://pf.kakao.com/_Hxjfnu/*********ifg@ifg@☞ 갤럭시 S**FE **원!ifg@☞ 갤럭시 S** **만원!ifg@☞ 갤럭시 S**울트라 **만원!ifg@☞ 갤럭시 Z플립*_*** *만원!ifg@☞ 아이폰**미니 **원!ifg@☞ 아이폰** ***,***원!ifg@☞ 아이폰** ***,***원!ifg@☞ 아이폰**프로 **만원!ifg@ifg@* **개월 약정 / 통신사별 가격상이ifg@ifg@□ 새 것같은 전시상품!! 오늘의 득템찬스ifg@- LG 워시타워 분리형 ***만원ifg@- LG 워시타워 일체형 ***만원ifg@- 삼성 비스포크 AI 원비다 ***만원ifg@ifg@□ 무더위 극복 에어컨 특별세일~ifg@- 캐리어 에어로 **단 ***만원!ifg@- 캐리어 오퍼스 ***만원!ifg@- 삼성 무풍슬림 ***만원!ifg@- 삼성 비스포크 갤러리 ***만원 (공청 가능)ifg@- LG **년형 뷰* ***만원!ifg@- LG 실속형 칸 ***만원!ifg@ifg@□ PC&노트북&모바일ifg@- 사무형, 게임형, 전문가형 순정부품 사용 조립PC ifg@- 노트북 LG그램 삼성북*프로 특별가ifg@- 노트북 삼성북 **만ifg@ifg@□ 시스템에어컨&냉난방기 ifg@- 사무실, 상가 냉난방기 신축주택 시스템에어컨 전문시공ifg@ifg@□ 혼수입주 가전 전문상담운영ifg@- NAVER검색 → 전자랜드 중동점 검색 → 사전상담 예약 ifg@- 사전예약 최저가 보장 시행ifg@ifg@#정수기,식기세척기,무선청소기,음식물처리기,안마의자,생활가전,세라젬V*#시스템에어컨ifg@#소상공인고객 특별할인 ifg@#군인,공무원 특별할인 ifg@#일부상품 제휴카드 혜택 포함가ifg@ifg@*월 최대혜택주간! 꼭 한번 들러주시면 성심껏 최선을 다하겠습니다. 감사합니다.ifg@ifg@ ifg@───────ifg@오래 쓰는 가전제품,ifg@고장 걱정 없이 사용하는 방법!ifg@ ifg@전자랜드X롯데손해보험,ifg@가전제품 *년 무상보증 서비스ifg@「가전제품 생활파워케어」 출시ifg@ ifg@가전 구매시 확인하세요ifg@ ifg@준법심의필 제****호(****.**.**)ifg@ifg@☎***-***-****ifg@무료수신거부 **********\n\n제목 : (광고)현대미아점 통합ifg@▶*O,OOO원할인권◀도착ifg@현대미아 설화수&헤라 ifg@☞기간:*월**일(금)~**일(일)ifg@☎문의:**-****-****ifg@ifg@▼**만원이상구매시▼ifg@【고급특대형 장바구니】증정ifg@【*O,OOO】매장할인ifg@【*,OOO】H.point할인ifg@【*%】할인(백.카드결제시)ifg@【기초*종】증정ifg@▶최종금액【**,***원】ifg@ifg@▼**만원이상구매시▼ifg@【고급특대형 장바구니】증정ifg@【*O,OOO】매장할인ifg@【*O,OOO】H.point할인ifg@【*O,OOO】*%할인(백.카드)ifg@▶최종금액【***,***원】ifg@------★**ml★----ifg@      【정품반용량】ifg@【스킨】자음생수**ml ifg@【스킨】자음생수**ml ifg@【스킨】자음생수**ml ifg@------★**ml★----ifg@      【정품반용량】ifg@【로션】자음생유액**ml ifg@【로션】자음생유액**ml ifg@【로션】자음생유액**ml ifg@-----★**ml★-----ifg@      【정품반용량】ifg@【에센스】자음생세럼*mlifg@【에센스】자음생세럼*ml ifg@【에센스】자음생세럼*ml ifg@【에센스】자음생세럼*ml ifg@【에센스】자음생세럼*mlifg@-----★**ml★------ifg@      【정품반용량】ifg@【크림】자음생크림*mlifg@【크림】자음생크림*mlifg@【크림】자음생크림*ml ifg@【크림】자음생크림*mlifg@【크림】자음생크림*mlifg@【크림】자음생크림*mlifg@---------------------ifg@ifg@■**만원이상구매시■ifg@【고급특대형 장바구니】증정ifg@【*O,OOO】매장할인ifg@【*O,OOO】H.point할인ifg@【*O,OOO】*%할인(백.카드)ifg@▶최종금액【***,***원】ifg@-----★**ml★------ifg@      【정품반용량】ifg@【프리미엄】진설수**ml ifg@【프리미엄】진설수**ml ifg@【프리미엄】진설수**ml ifg@-----★**ml★--------ifg@      【정품반용량】ifg@【프리미엄】진설유액**ml ifg@【프리미엄】진설유액**ml ifg@【프리미엄】진설유액**ml ifg@-----★**ml★-------ifg@      【정품반용량】ifg@【프리미엄】진설세럼*mlifg@【프리미엄】진설세럼*mlifg@【프리미엄】진설세럼*mlifg@【프리미엄】진설세럼*mlifg@【프리미엄】진설세럼*mlifg@-----★**ml★------ifg@      【정품반용량】ifg@【프리미엄】진설크림*mlifg@【프리미엄】진설크림*mlifg@【프리미엄】진설크림*mlifg@【프리미엄】진설크림*mlifg@【프리미엄】진설크림*mlifg@【프리미엄】진설크림*mlifg@-----------------------ifg@#기획세트와 중복불가ifg@#H포인트앱가입必ifg@#뷰티엔젤앱가입必ifg@#*인*회 참여가능ifg@#뷰티포인트사용금액제외ifg@#사은행사 중복 불가ifg@#문자 제시 고객의 한함ifg@#한정수량/품절가능ifg@#헤라또는설화수단일브랜드구매금액ifg@문의 : 현대미아점 통합/**-****-****ifg@무료수신거부 : ***-***-****\n\n[Web발신]ifg@(광고) 신세계면세점 명동점ifg@ifg@본 문자 수신 고객님께만ifg@신세계면세점 명동점 시크릿 혜택 드려요! ♪(´▽｀)/ifg@ifg@- 시크릿 행사 기간: ****.*.**(금)~**(일)ifg@ifg@♥시크릿 혜택 *♥ifg@김현중 님의 회원 계정에ifg@신세계면세점 명동점에서 결제 시 즉시 할인 가능한 쇼핑지원금 *종이 지급되었습니다.ifg@☞$***/*** 이상 구매 시 */*만원 즉시 사용 가능ifg@ifg@[유의사항]ifg@- 명동점 오프라인 매장에서 사용 가능(유효기간 : 발급일로부터 **일)ifg@- 일부 브랜드 사용 제외ifg@- 쇼핑지원금은 기타 쇼핑지원금과 중복 사용 불가ifg@- 본인 외 사용 및  ...

# %%
from konlpy.tag import Okt
from collections import Counter

# 명사 추출
okt = Okt()
nouns = okt.nouns(corpus)   # 개행문자/특수문자 자동 제거
nouns

# 단어 빈도수 계산
word_counts = Counter(nouns)
word_counts

# 불용어
ko_stopword = set('은 는 이 가 의 을 를 에 와 한 도 으로 및 값 오래'.split())

# 불용어 제거 + 길이 1 이하 단어 제거
filtered_words = {word: cnt for word, cnt in word_counts.items() if word not in ko_stopword and len(word) > 1}
filtered_words
# Out:
# {'발신': 266,
#  '광고': 262,
#  '한음': 1,
#  '대리점': 15,
#  '율량점': 1,
#  '류태자': 1,
#  '단골': 28,
#  '고객': 321,
#  '마지막': 33,
#  '최대': 132,
#  '할인': 409,
#  '기기': 35,
#  '변경': 32,
#  '플립': 10,
#  '원금': 38,
#  '기준': 48,
#  '매장': 114,
#  '추가': 179,
#  '구매': 258,
#  '금액': 72,
#  '용량': 14,
#  '장공': 1,
#  '오래오래': 1,
#  '사용': 116,
#  '소량': 5,
#  '조기': 41,
#  '종료': 63,
#  '가능성': 3,
#  '드림': 8,
#  '혜택': 408,
#  '보기': 35,
#  '공식': 26,
#  '홈페이지': 21,
#  '연결': 6,
#  '무료': 299,
#  '수신': 182,
#  '거부': 199,
#  '해지': 14,
#  '전자랜드': 18,
#  '동점': 2,
#  '최은순': 1,
#  '전국동시': 4,
#  '기간': 151,
#  '가전제품': 21,
#  '배달': 4,
#  '배민': 3,
#  '스토어': 22,
#  '바로': 54,
#  '혼수': 7,
#  '가전': 68,
#  '견적': 9,
#  '한번': 8,
#  '에어컨': 59,
#  '추천': 33,
#  '전문가': 12,
#  '냉장고': 24,
#  '건조기': 23,
#  '품목': 78,
#  '선풍기': 6,
#  '인치': 18,
#  '삼성': 72,
#  '아이폰': 30,
#  '미니': 16,
#  '갤럭시': 39,
#  '학생': 5,
#  '만원': 309,
#  '모바일': 35,
#  '행사': 188,
#  '내용': 45,
#  '울트라': 2,
#  '프로': 22,
#  '개월': 79,
#  '약정': 9,
#  '통신': 2,
#  '사별': 4,
#  '가격': 30,
#  '상이': 23,
#  '전시': 8,
#  '상품': 119,
#  '오늘': 20,
#  '득템': 11,
#  '찬스': 12,
#  '타워': 13,
#  '분리': 1,
#  '일체': 1,
#  '스포크': 2,
#  '무더위': 4,
#  '극복': 1,
#  '특별': 34,
#  '캐리어': 14,
#  '에어로': 4,
#  '오퍼스': 1,
#  '무풍': 7,
#  '슬림': 6,
#  '갤러리': 4,
#  '가능': 99,
#  '실속': 6,
#  '노트북': 6,
#  '사무': 3,
#  '게임': 2,
#  '순정': 2,
#  '부품': 12,
#  '조립': 2,
#  '그램': 2,
#  '성북': 4,
#  '시스템': 15,
#  '방기': 4,
#  '사무실': 4,
#  '상가': 4,
#  '신축': 3,
#  '주택': 7,
#  '전문': 6,
#  '시공': 6,
#  '상담': 65,
#  '운영': 17,
#  '검색': 3,
#  '중동': 1,
#  '사전': 26,
#  '예약': 83,
#  '사전예약': 23,
#  '최저': 24,
#  '보장': 11,
#  '시행': 7,
#  '식기세척기': 14,
#  '무선': 7,
#  '청소기': 3,
#  '음식물': 3,
#  '처리기': 3,
#  '안마': 4,
#  '의자': 5,
#  '생활': 26,
#  '세라': 2,
#  '공무원': 6,
#  '제휴': 33,
#  '카드': 65,
#  '포함': 14,
#  '주간': 2,
#  '성심껏': 3,
#  '최선': 5,
#  '고장': 5,
#  '걱정': 7,
#  '방법': 38,
#  '롯데': 48,
#  '손해': 7,
#  '보험': 87,
#  '무상': 35,
#  '보증': 17,
#  '서비스': 51,
#  '파워': 6,
#  '케어': 36,
#  '출시': 28,
#  '확인': 108,
#  '준법': 10,
#  '심의': 10,
#  '제목': 3,
#  '현대': 28,
#  '미아': 3,
#  '통합': 6,
#  '도착': 16,
#  '설화수': 1,
#  '헤라': 1,
#  '문의': 92,
#  '이상구': 5,
#  '고급': 11,
#  '특대': 3,
#  '장바구니': 4,
#  '증정': 361,
#  '결제': 34,
#  '기초': 6,
#  '최종': 8,
#  '정품': 16,
#  '스킨': 7,
#  '자음': 17,
#  '생수': 3,
#  '로션': 3,
#  '유액': 6,
#  '에센스': 7,
#  '크림': 17,
#  '생크림': 6,
#  '프리미엄': 60,
#  '진설': 17,
#  '중복': 30,
#  '불가': 32,
#  '참여': 70,
#  '제시': 9,
#  '품절': 27,
#  '신세계': 32,
#  '면세점': 7,
#  '명동': 6,
#  '문자': 83,
#  '시크릿': 13,
#  '김현중': 1,
#  '회원': 41,
#  '계정': 9,
#  '즉시': 15,
#  '쇼핑': 34,
#  '종이': 1,
#  '지급': 76,
#  '이상': 145,
#  '유의사항': 9,
#  '오프라인': 3,
#  '유효': 8,
#  '발급': 24,
#  '일로': 6,
#  '일부': 37,
#  '브랜드': 40,
#  '제외': 43,
#  '지원': 37,
#  '금은': 4,
#  '기타': 5,
#  '본인': 4,
#  '타인': 2,
#  '양도': 1,
#  '마이': 11,
#  '페이지': 16,
#  '가기': 25,
#  '장소': 19,
#  '센터': 53,
#  '여권': 2,
#  '당일': 17,
#  '영수증': 6,
#  '해당': 24,
#  '필수': 22,
#  '면세': 1,
#  '포인트': 55,
#  '트래블': 1,
#  '폴딩백': 1,
#  '이벤트': 160,
#  '내부': 3,
#  '사정': 13,
#  '전고지': 1,
#  '영업': 14,
#  '시간': 34,
#  '안내': 126,
#  '공휴일': 3,
#  '콜센터': 4,
#  '마트': 20,
#  '집사': 2,
#  '통장': 6,
#  '박은혜': 1,
#  '적립': 13,
#  '쿠폰': 161,
#  '콜리': 2,
#  '개이득': 1,
#  '이득': 1,
#  '여종': 1,
#  '반려동물': 1,
#  '용품': 4,
#  '식품': 15,
#  '천원': 71,
#  '자동': 19,
#  '대표': 14,
#  '회용': 1,
#  '패드': 7,
#  '정상': 13,
#  '신한': 16,
#  '농협카드': 6,
#  '피랩': 1,
#  '마음': 4,
#  '오리': 7,
#  '치킨': 13,
#  '라이스': 5,
#  '우유': 7,
#  '이나': 2,
#  '고양이': 1,
#  '츄르': 1,
#  '바코드': 6,
#  '스캔': 2,
#  '적용': 40,
#  '재고': 11,
#  '여름': 54,
#  '준비': 38,
#  '깜짝': 2,
#  '돌체': 3,
#  '스토': 3,
#  '스타벅스': 36,
#  '캡슐': 5,
#  '한정': 98,
#  '가세': 6,
#  '박스': 31,
#  '한정판': 3,
#  '텀블러': 1,
#  '아이스': 3,
#  '글라스': 1,
#  '스푼': 1,
#  '세트': 31,
#  '일간': 21,
#  '진행': 35,
#  '미리': 10,
#  '프로모션': 7,
#  '유의': 9,
#  '사항': 28,
#  '정기': 14,
#  '배송': 20,
#  '상황': 2,
#  '링크': 24,
#  '참고': 8,
#  '평일': 5,
#  '연락': 25,
#  '답변': 2,
#  '우리': 20,
#  '한우': 113,
#  '세리': 2,
#  '스마트': 6,
#  '전단': 10,
#  '안심': 28,
#  '주문': 29,
#  '매일': 14,
#  '야채': 9,
#  '청과': 5,
#  '지역': 5,
#  '일별': 1,
#  '화요일': 1,
#  '암소': 22,
#  '채끝': 2,
#  '등심': 20,
#  '초특': 5,
#  '앞다리': 10,
#  '불고기': 30,
#  '등급': 33,
#  '대박': 8,
#  '진시': 20,
#  '판매': 39,
#  '갈비': 11,
#  '등뼈': 5,
#  '부채살': 4,
#  '구이': 3,
#  '육회': 12,
#  '소스': 13,
#  '거리': 15,
#  '양지': 8,
#  '잡뼈': 2,
#  '써비스': 1,
#  '명품': 2,
#  '훈제': 4,
#  '대란': 6,
#  '양념': 24,
#  '수제': 15,
#  '돈가스': 3,
#  '돼지갈비': 5,
#  '떡갈비': 4,
#  '사골곰국': 1,
#  '파우치': 2,
#  '윤병섭님': 1,
#  '환급': 18,
#  '모두': 14,
#  '축하': 23,
#  '국외': 21,
#  '한국': 40,
#  '거래소': 2,
#  '해운대': 5,
#  '비치': 3,
#  '매물': 2,
#  '포웰': 1,
#  '부산': 17,
#  '분양': 40,
#  '일반': 19,
#  '가야': 1,
#  '우대': 2,
#  '주중': 1,
#  '동래': 1,
#  '전세': 2,
#  '객실': 2,
#  '오션': 4,
#  '풀이': 1,
#  '세계': 4,
#  '트리': 3,
#  '직통': 4,
#  '멤버십': 34,
#  '공통': 3,
#  '편의점': 10,
#  '베이커리': 5,
#  '파리': 14,
#  '바게뜨': 4,
#  '뚜레주르': 4,
#  '파리크라상': 4,
#  '주요': 5,
#  '매달': 7,
#  '네이버': 19,
#  '플러스': 12,
#  '구독': 67,
#  '유독': 3,
#  '유튜브': 8,
#  '밀리': 3,
#  '서재': 4,
#  '메가박스': 4,
#  '예매': 9,
#  '오디오북': 3,
#  '리디': 3,
#  '셀렉': 3,
#  '요기': 3,
#  '공차': 3,
#  '할리스': 3,
#  '월드': 4,
#  '에버랜드': 3,
#  '아쿠아리움': 3,
#  '서울': 13,
#  '스카이': 3,
#  '이용권': 4,
#  '지금': 39,
#  '영화': 4,
#  '만족도': 28,
#  '조사': 35,
#  '개인': 7,
#  '급전': 1,
#  '대출': 5,
#  '누구': 6,
#  '조건': 38,
#  '승인': 3,
#  '카카오': 31,
#  '비대': 6,
#  '워킹': 1,
#  '신제품': 15,
#  '이밴트': 1,
#  '최초': 7,
#  '유일': 2,
#  '진짜': 6,
#  '진동': 3,
#  '신발': 4,
#  '골든타임': 2,
#  '혈류': 1,
#  '기념': 23,
#  '자기': 5,
#  '방문': 70,
#  '차도': 1,
#  '한잔': 1,
#  '기회': 18,
#  '잡고': 2,
#  '건강': 28,
#  '영등포': 2,
#  '익산': 2,
#  '농협': 9,
#  '로컬': 6,
#  '푸드': 6,
#  '직매': 2,
#  '등점': 2,
#  '밴드': 4,
#  '금토일': 1,
#  '축산': 11,
#  '코너': 28,
#  '돈암': 8,
#  '돼지': 19,
#  '삼겹살': 15,
#  '목살': 5,
#  '족발': 1,
#  '주물': 2,
#  '하림': 4,
#  '닭다리': 1,
#  '정육': 7,
#  '수산': 10,
#  '왕궁': 1,
#  '우렁이': 1,
#  '갑오징어': 2,
#  '마리': 41,
#  '오징어': 10,
#  '농산': 3,
#  '참외': 12,
#  '봉지': 11,
#  '천도': 6,
#  '복숭아': 10,
#  '팽이버섯': 2,
#  '묶음': 2,
#  '오이': 9,
#  '개입': 9,
#  '공산': 5,
#  '특급': 5,
#  '레비': 1,
#  '라임': 1,
#  '레몬': 5,
#  '플레인': 2,
#  '수량': 28,
#  '오뚜기': 13,
#  '카레': 1,
#  '약간': 1,
#  '햇반': 4,
#  '팔도': 4,
#  '비빔면': 6,
#  '레쉬': 2,
#  '리지': 8,
#  '백설': 10,
#  '소시지': 1,
#  '느낌': 3,
#  '오버': 1,
#  '보쌈': 2,
#  '사태': 5,
#  '탕용': 3,
#  '차돌박이': 6,
#  '샤브샤브': 3,
#  '스테이크': 2,
#  '타임세일': 8,
#  '오후': 18,
#  '수박': 16,
#  '팩귤': 1,
#  '송이버섯': 2,
#  '깻잎': 5,
#  '빵가루': 2,
#  '새우': 5,
#  '건조': 3,
#  '박대': 1,
#  '선동': 1,
#  '제주': 15,
#  '갈치': 7,
#  '동태': 2,
#  '능이': 1,
#  '닭백숙': 1,
#  '공동': 4,
#  '바로가기': 11,
#  '오전': 13,
#  '무조건': 5,
#  '사은': 71,
#  '이점': 3,
#  '양해': 5,
#  '국제': 46,
#  '대한민국': 4,
#  '예정': 35,
#  '공항': 6,
#  '마중': 3,
#  '울릉도': 1,
#  '마가': 4,
#  '보감': 4,
#  '지대': 7,
#  '천연': 2,
#  '비아그라': 1,
#  '한시': 3,
#  '유예': 1,
#  '마감': 15,
#  '이제': 20,
#  '절대': 5,
#  '다시': 8,
#  '예전': 1,
#  '그대로': 5,
#  '더블': 22,
#  '구성': 8,
#  '기존': 11,
#  '침향': 22,
#  '뭔가': 1,
#  '가지': 15,
#  '이슬': 2,
#  '크게': 1,
#  '기력': 1,
#  '정력': 1,
#  '지구력': 1,
#  '체력': 2,
#  '기능': 11,
#  '향상': 1,
#  '혈액': 1,
#  '순환': 3,
#  '관문': 1,
#  '비수리': 1,
#  '오자': 1,
#  '성분': 3,
#  '남자': 2,
#  '자존심': 1,
#  '제품': 47,
#  '기운': 1,
#  '얼마나': 1,
#  '지인': 2,
#  '가족': 11,
#  '친구': 19,
#  '등등': 1,
#  '개시': 1,
#  '선물': 28,
#  '전화': 30,
#  '주시': 11,
#  '울릉': 1,
#  '산림': 1,
#  '총괄': 2,
#  '실장': 12,
#  '혜란': 2,
#  '구미': 1,
#  '칠곡': 3,
#  '축협': 2,
#  '하나로마트': 4,
#  '기소진': 7,
#  '돈육': 2,
#  '브리': 1,
#  '냉장': 9,
#  '갈매기살': 1,
#  '냉동': 4,
#  '과일': 4,
#  '도선': 2,
#  '하우스': 2,
#  '토마토': 7,
#  '바나나': 8,
#  '성주': 1,
#  '채소': 4,
#  '호박': 1,
#  '청양고추': 4,
#  '단호박': 3,
#  '애호박': 6,
#  '가시': 3,
#  '상추': 1,
#  '생물': 6,
#  '고등어': 10,
#  '손질': 3,
#  '전복': 5,
#  '꼬막': 1,
#  '물회': 4,
#  '육수': 5,
#  '모듬회': 1,
#  '숙회': 1,
#  '해표': 2,
#  '순창': 2,
#  '골드': 7,
#  '고추장': 7,
#  '핫도그': 2,
#  '치즈': 4,
#  '크리스': 2,
#  '코디': 1,
#  '내추럴': 2,
#  '미용': 1,
#  '티슈': 4,
#  '수퍼': 4,
#  '타이': 3,
#  '샤프란': 2,
#  '릴렉': 1,
#  '싱아': 1,
#  '로마': 1,
#  '코튼': 1,
#  '핑크': 2,
#  '센세이션': 1,
#  '카톡': 7,
#  '예찬': 1,
#  '여러분': 6,
#  '도마': 1,
#  '변동': 3,
#  '구역': 2,
#  '대장': 1,
#  '아파트': 17,
#  '힐스테이트': 8,
#  '가장': 14,
#  '퍼스트': 1,
#  '선착순': 50,
#  '지정': 9,
#  '계약금': 21,
#  '대전': 6,
#  '서구': 2,
#  '양제': 1,
#  '실시': 4,
#  '최화영': 1,
#  '과장': 7,
#  '정관': 22,
#  '더위': 10,
#  '체험': 16,
#  '시점': 8,
#  '홍삼': 8,
#  '톤류': 1,
#  '모든': 22,
#  '대상': 60,
#  '유저': 3,
#  '소진': 17,
#  '버스': 9,
#  '정류': 3,
#  '아이': 17,
#  '패스': 9,
#  '현재': 10,
#  '전남': 1,
#  '조례': 1,
#  '카다': 5,
#  '로그': 5,
#  '방역': 5,
#  '위생': 6,
#  '관리': 21,
#  '라이브': 28,
#  '폭염': 3,
#  '온라인': 16,
#  '도전': 2,
#  '스탠드': 9,
#  '절호': 2,
#  '여기': 3,
#  '우수': 5,
#  '하나': 5,
#  '기사': 2,
#  '이내': 11,
#  '설치': 20,
#  '전자': 29,
#  '할부': 7,
#  '접수': 4,
#  '한해': 6,
#  '완료': 15,
#  '별도': 16,
#  '택배': 1,
#  '커피': 11,
#  '전월': 2,
#  '이용': 72,
#  '실적': 10,
#  '전일': 1,
#  '마케팅': 16,
#  '신동': 2,
#  '발송': 24,
#  '신한카드': 15,
#  '고학': 1,
#  '상품권': 110,
#  '숫자': 2,
#  '답장': 15,
#  '신청': 64,
#  '상세': 6,
#  '시불': 3,
#  '합산': 20,
#  '다음': 4,
#  '말일': 2,
#  '제공': 72,
#  '디스커버': 3,
#  '하루': 15,
#  '분만': 2,
#  '투자': 16,
#  '트렌드': 2,
#  '강사': 2,
#  '최신': 9,
#  '정보': 10,
#  '주의': 5,
#  '당사': 10,
#  '등록': 14,
#  '휴대폰': 17,
#  '번호': 21,
#  '회신': 5,
#  '응모': 14,
#  '익월': 1,
#  '중순': 1,
#  '이후': 11,
#  '체크': 2,
#  '법인': 4,
#  '기프트': 2,
#  '교통': 5,
#  '요금': 25,
#  '비용': 5,
#  '부담': 13,
#  '계약': 53,
#  '체결': 17,
#  '회비': 6,
#  '설명': 17,
#  '약관': 9,
#  '참조': 5,
#  '금융': 17,
#  '소비자보호법': 1,
#  '대해': 5,
#  '권리': 2,
#  '신용카드': 8,
#  '부적정': 1,
#  '경우': 10,
#  '연체': 3,
#  '단기': 1,
#  '사유': 3,
#  '발생': 11,
#  '신용': 6,
#  '평점': 8,
#  '제한': 12,
#  '대금': 5,
#  '수수료': 3,
#  '상환': 4,
#  '능력': 2,
#  '대비': 11,
#  '과도': 1,
#  '하락': 7,
#  '거래': 2,
#  '불이익': 2,
#  '일정': 8,
#  '변제': 2,
#  '의무': 7,
#  '감시': 2,
#  '일광': 5,
#  '유림': 1,
#  '노르웨이숲': 1,
#  '포레': 1,
#  '신도시': 3,
#  '끝판': 3,
#  '등장': 1,
#  '면적': 3,
#  '전용': 10,
#  '단지': 18,
#  '세대': 41,
#  '조경': 2,
#  '하이': 2,
#  '앤드': 1,
#  '커뮤니티': 5,
#  '리딩': 4,
#  '탄생': 1,
#  '찾기': 2,
#  '대형': 5,
#  '평형': 19,
#  '보유': 8,
#  '타입': 19,
#  '광초': 1,
#  '동향': 1,
#  '주력': 1,
#  '배치': 1,
#  '일광역': 1,
#  '도보': 6,
#  '물산': 1,
#  '시설': 4,
#  '지하': 6,
#  '지상': 8,
#  '호실': 2,
#  '담당자': 5,
#  '안창': 1,
#  '연락처': 5,
#  '변지영': 1,
#  '채널': 14,
#  '돌파': 5,
#  '단독': 25,
#  '당첨': 9,
#  '적립금': 7,
#  '추첨': 36,
#  '아래': 25,
#  '메세지': 8,
#  '일자': 11,
#  '동의': 38,
#  '라이프': 10,
#  '본사': 9,
#  '쇼핑몰': 8,
#  '에스티': 2,
#  '로더': 2,
#  '방송': 38,
#  '햇빛': 1,
#  '날씨': 3,
#  '루틴': 1,
#  '피부': 7,
#  '즉각': 1,
#  '진정': 1,
#  '도움': 5,
#  '갈색': 4,
#  '레스큐': 1,
#  '솔루션': 2,
#  '입장': 7,
#  '데이': 6,
#  '디럭스': 1,
#  '대별': 29,
#  '파운데이션': 1,
#  '브러쉬': 1,
#  '리뷰': 12,
#  '통해': 21,
#  '퓨어': 2,
#  '컬러': 2,
#  '립스틱': 1,
#  '레벨': 1,
#  '어스': 2,
#  '파스텔': 3,
#  '오픈': 24,
#  '국민카드': 1,
#  '닥스': 2,
#  '전원': 12,
#  '케이스': 9,
#  '포멜카멜레': 1,
#  '플라자': 20,
#  '수원': 8,
#  '초대장': 3,
#  '장르': 9,
#  '단일': 17,
#  '웰컴': 6,
#  '캐시': 6,
#  '청구': 4,
#  '상기': 5,
#  '점내': 3,
#  '지물': 10,
#  '더욱': 8,
#  '데스크': 12,
#  '골든': 5,
#  '금주': 13,
#  '원점': 8,
#  '뉴스': 10,
#  '시즌': 7,
#  '창립': 3,
#  '주년': 13,
#  '페리': 3,
#  '도넛': 2,
#  '박은미': 1,
#  '스페셜': 12,
#  '세부': 5,
#  '알레': 4,
#  '르망': 5,
#  '침구': 6,
#  '스핑크스': 1,
#  '광주': 10,
#  '첨단': 8,
#  '주소': 17,
#  '광산구': 1,
#  '임방울': 1,
#  '인증': 26,
#  '코드': 6,
#  '동원': 7,
#  '정육점': 2,
#  '주차': 9,
#  '전화번호': 7,
#  '사시미': 5,
#  '직접': 9,
#  '천엽': 2,
#  '이번': 23,
#  '고기': 12,
#  '갈비살': 7,
#  '얼마': 2,
#  '일요일': 10,
#  '사골곰탕': 3,
#  '듬뿍': 1,
#  '곰탕': 2,
#  '볶음': 4,
#  '백숙': 2,
#  '껍질': 1,
#  '돈까스': 4,
#  '양배추': 3,
#  '샐러드': 2,
#  '왕란': 2,
#  '남평': 2,
#  '파머스': 3,
#  '마켓': 3,
#  '개점': 2,
#  '가입': 51,
#  '사랑': 6,
#  '슈퍼': 3,
#  '오브': 5,
#  '일시': 2,
#  '본점': 11,
#  '감사': 13,
#  '먹거리': 2,
#  '왕만': 2,
#  '찐빵': 1,
#  '다도': 2,
#  '마늘': 7,
#  '남해안': 2,
#  '절임': 2,
#  '멸치': 3,
#  '병어': 1,
#  '영광': 4,
#  '굴비': 2,
#  '민물장어': 1,
#  '러시': 4,
#  '아산': 6,
#  '바베큐': 2,
#  '조미': 1,
#  '농산팀': 1,
#  '대파': 3,
#  '인큐': 2,
#  '케익': 1,
#  '도너츠': 1,
#  '옥수수': 2,
#  '파운드': 1,
#  '공산품': 7,
#  '설탕': 5,
#  '청정': 5,
#  '간장': 7,
#  '센트': 6,
#  '바디': 16,
#  '워시': 7,
#  '스크럽워시': 1,
#  '자연': 5,
#  '솔잎': 1,
#  '베이': 5,
#  '킹소': 4,
#  '피톤': 1,
#  '치드': 1,
#  '양반': 1,
#  '부각': 2,
#  '스타': 14,
#  '맥스': 2,
#  '프레': 4,
#  '파격': 4,
#  '진라면': 3,
#  '강변': 2,
#  '지점': 16,
#  '장기': 20,
#  '신규': 28,
#  '드릴': 7,
#  '매월': 8,
#  '유플투쁠': 11,
#  '내일': 6,
#  '던킨': 5,
#  '레고랜드': 4,
#  '파크': 4,
#  '입장권': 4,
#  '비욘드': 11,
#  '토탈': 4,
#  '베이직': 7,
#  '아모레퍼시픽': 4,
#  '뷰티': 4,
#  '피싱': 4,
#  '해킹': 4,
#  '백만원': 6,
#  '보상': 21,
#  '듀얼': 6,
#  '넘버': 4,
#  '데이터': 10,
#  '컬러링': 4,
#  '오빠': 7,
#  '기억': 3,
#  '엘지': 12,
#  '유플러스': 51,
#  '인터넷': 32,
#  '특판': 4,
#  '사운드': 2,
#  '원상': 2,
#  '선택': 16,
#  '최소': 3,
#  '세탁기': 12,
#  '탄현': 1,
#  '청주': 4,
#  '센트럴': 3,
#  '관람': 13,
#  '견본주택': 6,
#  '연장': 8,
#  '야간': 1,
#  '청주시': 1,
#  ...}

# %%
# %pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from wordcloud) (2.4.3)
# Requirement already satisfied: pillow in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from wordcloud) (12.2.0)
# Requirement already satisfied: matplotlib in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (26.1)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Word Cloud 객체 생성

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(
    width=800,
    height=800,
    background_color='white',
    font_path='C:\\Windows\\Fonts\\malgun.ttf'
).generate_from_frequencies(filtered_words)

# %%
# 시각화
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# 이미지 저장
wordcloud.to_file('ko_sms_spam_wordcloud.png')

# %%
# 만약 전처리 없이 만들어본다면?
corpus = corpus.replace('\n', '')
word_counts = Counter(corpus)

wordcloud = WordCloud(
    width=800,
    height=800,
    background_color='white',
    font_path='C:\\Windows\\Fonts\\malgun.ttf'
).generate_from_frequencies(word_counts)

plt.figure(figsize=(10, 10))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
