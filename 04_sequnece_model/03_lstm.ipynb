# %% [markdown]
# # LSTM
#
#
# LSTM(Long Short-Term Memory)은 **순환신경망(RNN, Recurrent Neural Network)** 의 일종으로, RNN의 단점인 **장기 의존성 문제** 를 해결하기 위해 고안된 신경망 구조이다.
#
# **LSTM의 주요 특징**
# 1. **장기 의존성(Long-Term Dependency) 처리**
#    - 일반적인 RNN은 시간이 길어질수록 과거의 정보를 잘 기억하지 못하는 **기울기 소멸(Gradient Vanishing)** 문제가 발생한다.
#    - LSTM은 **Cell State**와 **게이트 구조**를 통해 중요한 정보를 장기적으로 유지할 수 있다.
#
# 2. **게이트(Gates) 구조**
#    - LSTM은 정보를 선택적으로 기억하거나 잊게 해주는 3가지 게이트로 구성된다:
#      - **입력 게이트(Input Gate):** 새로운 정보를 얼마나 저장할지 결정한다.
#      - **망각 게이트(Forget Gate):** 기존 정보를 얼마나 잊을지 결정한다.
#      - **출력 게이트(Output Gate):** 현재 상태를 출력에 얼마나 반영할지 결정한다.
#
# 3. **Cell State**
#    - 네트워크의 **기억 장치** 역할을 하며, 중요하지 않은 정보는 제거하고 중요한 정보는 유지한다.
#
#
# **LSTM의 구조**
#
# ![](https://d.pr/i/iPf2jG+)
#
# 아래는 LSTM의 한 타임스텝(time step)에서 이루어지는 연산 과정이다:
#
# 1. **망각 게이트 (Forget Gate)**
#     * 이전 상태 $h_{t-1}$와 입력 $x_t$를 통해 제거할 정보를 결정한다.
#
# $$
# f_t = \sigma(W_f \cdot [h_{t-1}, x_t] + b_f)
# $$
#
# 2. **입력 게이트 (Input Gate)**
#     - 입력 게이트 $i_t$와 새로운 정보 $\tilde{C}_t$를 결합하여 Cell State에 반영할 정보를 생성한다.
#
# $$
# i_t = \sigma(W_i \cdot [h_{t-1}, x_t] + b_i)
# $$
#
# $$
# \tilde{C}_t = \tanh(W_C \cdot [h_{t-1}, x_t] + b_C)
# $$
#
# 3. **Cell State 업데이트**
#     * 이전 Cell State $C_{t-1}$와 새로운 정보의 조합으로 현재 Cell State를 업데이트한다.
#
# $$
# C_t = f_t \cdot C_{t-1} + i_t \cdot \tilde{C}_t
# $$
#
#
#
# 4. **출력 게이트 (Output Gate)**
#     * 출력 게이트 $o_t$와 업데이트된 Cell State $C_t$를 통해 새로운 은닉 상태 $h_t$를 계산한다.
#
# $$
# o_t = \sigma(W_o \cdot [h_{t-1}, x_t] + b_o)
# $$
#
# $$
# h_t = o_t \cdot \tanh(C_t)
# $$
#
# **LSTM의 장점**
#
# 1. **장기 시퀀스 데이터 처리**: 시간의 흐름에 따라 발생하는 데이터를 잘 학습한다.
# 2. **텍스트, 음성, 시계열 데이터에 적합**: 언어 모델링, 번역, 주가 예측, 음성 인식 등 다양한 분야에서 활용된다.
# 3. **기울기 소멸 문제 해결**: Cell State와 게이트 구조 덕분에 학습이 안정적이다.
#
# **추가 활용**
#
# - **양방향 LSTM (Bidirectional LSTM)**: 양방향으로 데이터를 처리하여 더 많은 정보를 학습할 수 있다.
# - **Stacked LSTM**: LSTM 레이어를 여러 층 쌓아 더 복잡한 패턴을 학습한다.

# %% [markdown]
# ## LSTM 구조

# %%
import torch
import torch.nn as nn

batch_size = 2
seq_len = 3
input_size = 4
hidden_size = 5

x = torch.randn(batch_size, seq_len, input_size)
print('x.shape', x.shape)

lstm = nn.LSTM(input_size, hidden_size, batch_first=True)
output, (hidden, cell) = lstm(x)

print('output : ', output.shape)    # (batch_size, seq_len, hidden_size)
print('hidden : ', hidden.shape)    # (num_layer, batch_size, hidden_size)
print('cell : ', cell.shape)        # (num_layer, batch_size, hidden_size)
# Out:
# x.shape torch.Size([2, 3, 4])
# output :  torch.Size([2, 3, 5])
# hidden :  torch.Size([1, 2, 5])
# cell :  torch.Size([1, 2, 5])

# %% [markdown]
# ## IMDB 리뷰 감정 분석

# %%
# keras 제공 imdb 데이터 셋
from tensorflow.keras.datasets import imdb

# 자주 사용 되는 300개의 단어로 제한
vocab_size = 300

# 시퀀스 길이 제한
seq_len = 100

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

X_test = X_test[:10000]
y_test = y_test[:10000]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# c:\Users\Playdata\AppData\Local\miniforge3\envs\dl_nlp_env\Lib\site-packages\numpy\lib\_format_impl.py:838: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   array = pickle.load(fp, **pickle_kwargs)
# (25000,) (25000,)
# (10000,) (10000,)

# %%
# 문장 길이 맞추기
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train = pad_sequences(X_train, maxlen=seq_len, padding='post', truncating='post')
X_test = pad_sequences(X_test, maxlen=seq_len, padding='post', truncating='post')

# %%
# ont-hot encoding
# X 입력값 (batch_size, seq_len, vocab_size)
from tensorflow.keras.utils import to_categorical

X_train_onehot = to_categorical(X_train, num_classes=vocab_size)
X_test_onehot = to_categorical(X_test, num_classes=vocab_size)
print(X_train_onehot.shape)
print(X_test_onehot.shape)
# Out:
# (25000, 100, 300)
# (10000, 100, 300)

# %%
# tensor 변환
X_train_onehot = torch.tensor(X_train_onehot, dtype=torch.float)
X_test_onehot = torch.tensor(X_test_onehot, dtype=torch.float)

y_train = torch.tensor(y_train, dtype=torch.float).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.float).unsqueeze(1)

print(X_train_onehot.shape, y_train.shape)
print(X_test_onehot.shape, y_test.shape)
# Out:
# torch.Size([25000, 100, 300]) torch.Size([25000, 1])
# torch.Size([10000, 100, 300]) torch.Size([10000, 1])

# %% [markdown]
# ## LSTM + One-Hot Encoding

# %%
# LSTM 모델 생성
class LSTMSentimenticNet(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        """
        Params:
        - input_dim : 원핫 인코딩 기준 단어 수
        - hidden_dim : RNN 뉴런 수
        """
        super().__init__()
        self.lstm = nn.LSTM(input_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        _, (hidden, cell) = self.lstm(x)
        output = self.fc(hidden[-1]) # (num_layer, batch_size, hidden_dim)
        return output

input_dim = vocab_size
hidden_dim = 16
output_dim = 1

model = LSTMSentimenticNet(input_dim, hidden_dim, output_dim)
model
# Out:
# LSTMSentimenticNet(
#   (lstm): LSTM(300, 16, batch_first=True)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
# 모델 파라미터 확인
total_params = 0
for name, param in model.named_parameters():
    # print(name, param)
    if param.requires_grad:                 # 미분 가능한 파라미터만 
        param_count = param.numel()         # 모든 가중치 개수
        total_params += param_count         
        print(f'{name:<20} {str(list(param.shape)):<30} {param_count}')

print(f'Total Trainable Parameters : {total_params}')
# Out:
# lstm.weight_ih_l0    [64, 300]                      19200
# lstm.weight_hh_l0    [64, 16]                       1024
# lstm.bias_ih_l0      [64]                           64
# lstm.bias_hh_l0      [64]                           64
# fc.weight            [1, 16]                        16
# fc.bias              [1]                            1
# Total Trainable Parameters : 20369

# %%
# 학습/검증/평가 데이터 준비
from torch.utils.data import random_split, DataLoader, TensorDataset

batch_size = 64
train_size = int(len(X_train_onehot) * 0.8)
val_size = len(X_train_onehot) - train_size

train_dataset, val_dataset = random_split(TensorDataset(X_train_onehot, y_train), [train_size, val_size])
test_dataset = TensorDataset(X_test_onehot, y_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
from torch.optim import Adam

# 손실 함수
criterion = nn.BCEWithLogitsLoss()
# 옵티마이저
optimizer = Adam(model.parameters(), lr=0.0001)

epochs = 100

# 시각화를 위한 기록
train_losses, val_losses, train_accs, val_accs = [], [], [], []

# 조기 종료 관련
early_stopping_patience = 20
best_val_loss = float('inf')
early_stopping_counter = 0

for epoch in range(epochs):
    total_loss, correct, total = 0, 0, 0

    # 학습
    model.train()
    for inputs, labels in train_dataloader:
        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        # 배치 로그
        total_loss += loss.item()
        prob = torch.sigmoid(output)
        pred = (prob >= 0.5).float()
        correct += (pred == labels).sum().item()
        total += labels.size(0)
    
    # 에폭 로그
    train_loss = total_loss / len(train_dataloader)
    train_losses.append(train_loss)
    train_acc = correct / total
    train_accs.append(train_acc)

    # 검증
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for val_inputs, val_labels in val_dataloader:

            output = model(val_inputs)
            loss = criterion(output, val_labels)

            # 배치 로그
            val_loss += loss.item()
            prob = torch.sigmoid(output)
            pred = (prob >= 0.5).float()
            val_correct += (pred == val_labels).sum().item()
            val_total += val_labels.size(0)

    # 에폭 로그
    val_loss = val_loss / len(val_dataloader)
    val_losses.append(val_loss)
    val_acc = val_correct / val_total
    val_accs.append(val_acc)

    print(f'Epoch {epoch + 1}/{epochs}: Train Loss {train_loss:.4f} \
          Train Acc {train_acc:.4f} Val Loss {val_loss:.4f} Val Acc {val_acc:.4f}')
    
    # 조기종료
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early stopped at Epoch {epoch + 1}')
            break
# Out:
# Epoch 1/100: Train Loss 0.6932           Train Acc 0.4940 Val Loss 0.6932 Val Acc 0.4874
# Epoch 2/100: Train Loss 0.6930           Train Acc 0.4985 Val Loss 0.6930 Val Acc 0.5048
# Epoch 3/100: Train Loss 0.6928           Train Acc 0.5158 Val Loss 0.6928 Val Acc 0.5154
# Epoch 4/100: Train Loss 0.6926           Train Acc 0.5219 Val Loss 0.6926 Val Acc 0.5190
# Epoch 5/100: Train Loss 0.6923           Train Acc 0.5271 Val Loss 0.6924 Val Acc 0.5218
# Epoch 6/100: Train Loss 0.6919           Train Acc 0.5361 Val Loss 0.6921 Val Acc 0.5214
# Epoch 7/100: Train Loss 0.6913           Train Acc 0.5412 Val Loss 0.6916 Val Acc 0.5238
# Epoch 8/100: Train Loss 0.6904           Train Acc 0.5422 Val Loss 0.6908 Val Acc 0.5298
# Epoch 9/100: Train Loss 0.6882           Train Acc 0.5555 Val Loss 0.6863 Val Acc 0.5484
# Epoch 10/100: Train Loss 0.6701           Train Acc 0.5979 Val Loss 0.6668 Val Acc 0.6106
# Epoch 11/100: Train Loss 0.6572           Train Acc 0.6228 Val Loss 0.6553 Val Acc 0.6268
# Epoch 12/100: Train Loss 0.6442           Train Acc 0.6423 Val Loss 0.6429 Val Acc 0.6436
# Epoch 13/100: Train Loss 0.6270           Train Acc 0.6660 Val Loss 0.6263 Val Acc 0.6696
# Epoch 14/100: Train Loss 0.6165           Train Acc 0.6755 Val Loss 0.6166 Val Acc 0.6774
# Epoch 15/100: Train Loss 0.6070           Train Acc 0.6846 Val Loss 0.6053 Val Acc 0.6908
# Epoch 16/100: Train Loss 0.5977           Train Acc 0.6947 Val Loss 0.5965 Val Acc 0.6990
# Epoch 17/100: Train Loss 0.5879           Train Acc 0.7034 Val Loss 0.5880 Val Acc 0.6968
# Epoch 18/100: Train Loss 0.5791           Train Acc 0.7087 Val Loss 0.5800 Val Acc 0.7102
# Epoch 19/100: Train Loss 0.5726           Train Acc 0.7125 Val Loss 0.5727 Val Acc 0.7120
# Epoch 20/100: Train Loss 0.5652           Train Acc 0.7168 Val Loss 0.5652 Val Acc 0.7140
# Epoch 21/100: Train Loss 0.5583           Train Acc 0.7238 Val Loss 0.5595 Val Acc 0.7182
# Epoch 22/100: Train Loss 0.5526           Train Acc 0.7264 Val Loss 0.5560 Val Acc 0.7194
# Epoch 23/100: Train Loss 0.5487           Train Acc 0.7285 Val Loss 0.5533 Val Acc 0.7210
# Epoch 24/100: Train Loss 0.5435           Train Acc 0.7319 Val Loss 0.5522 Val Acc 0.7210
# Epoch 25/100: Train Loss 0.5400           Train Acc 0.7332 Val Loss 0.5480 Val Acc 0.7208
# Epoch 26/100: Train Loss 0.5360           Train Acc 0.7378 Val Loss 0.5407 Val Acc 0.7276
# Epoch 27/100: Train Loss 0.5330           Train Acc 0.7373 Val Loss 0.5415 Val Acc 0.7244
# Epoch 28/100: Train Loss 0.5305           Train Acc 0.7402 Val Loss 0.5372 Val Acc 0.7306
# Epoch 29/100: Train Loss 0.5282           Train Acc 0.7423 Val Loss 0.5347 Val Acc 0.7310
# Epoch 30/100: Train Loss 0.5256           Train Acc 0.7421 Val Loss 0.5343 Val Acc 0.7298
# Epoch 31/100: Train Loss 0.5238           Train Acc 0.7429 Val Loss 0.5327 Val Acc 0.7330
# Epoch 32/100: Train Loss 0.5218           Train Acc 0.7412 Val Loss 0.5310 Val Acc 0.7310
# Epoch 33/100: Train Loss 0.5208           Train Acc 0.7450 Val Loss 0.5290 Val Acc 0.7338
# Epoch 34/100: Train Loss 0.5184           Train Acc 0.7452 Val Loss 0.5290 Val Acc 0.7338
# Epoch 35/100: Train Loss 0.5172           Train Acc 0.7457 Val Loss 0.5319 Val Acc 0.7308
# Epoch 36/100: Train Loss 0.5159           Train Acc 0.7472 Val Loss 0.5285 Val Acc 0.7300
# Epoch 37/100: Train Loss 0.5155           Train Acc 0.7465 Val Loss 0.5258 Val Acc 0.7316
# Epoch 38/100: Train Loss 0.5144           Train Acc 0.7478 Val Loss 0.5258 Val Acc 0.7332
# Epoch 39/100: Train Loss 0.5131           Train Acc 0.7474 Val Loss 0.5245 Val Acc 0.7314
# Epoch 40/100: Train Loss 0.5116           Train Acc 0.7479 Val Loss 0.5262 Val Acc 0.7364
# Epoch 41/100: Train Loss 0.5111           Train Acc 0.7486 Val Loss 0.5276 Val Acc 0.7322
# Epoch 42/100: Train Loss 0.5099           Train Acc 0.7494 Val Loss 0.5249 Val Acc 0.7316
# Epoch 43/100: Train Loss 0.5103           Train Acc 0.7523 Val Loss 0.5236 Val Acc 0.7324
# Epoch 44/100: Train Loss 0.5087           Train Acc 0.7510 Val Loss 0.5246 Val Acc 0.7322
# Epoch 45/100: Train Loss 0.5081           Train Acc 0.7503 Val Loss 0.5233 Val Acc 0.7332
# Epoch 46/100: Train Loss 0.5074           Train Acc 0.7499 Val Loss 0.5247 Val Acc 0.7312
# Epoch 47/100: Train Loss 0.5070           Train Acc 0.7506 Val Loss 0.5257 Val Acc 0.7300
# Epoch 48/100: Train Loss 0.5062           Train Acc 0.7504 Val Loss 0.5224 Val Acc 0.7332
# Epoch 49/100: Train Loss 0.5056           Train Acc 0.7503 Val Loss 0.5240 Val Acc 0.7340
# Epoch 50/100: Train Loss 0.5053           Train Acc 0.7503 Val Loss 0.5220 Val Acc 0.7344
# Epoch 51/100: Train Loss 0.5051           Train Acc 0.7510 Val Loss 0.5255 Val Acc 0.7326
# Epoch 52/100: Train Loss 0.5035           Train Acc 0.7531 Val Loss 0.5229 Val Acc 0.7344
# Epoch 53/100: Train Loss 0.5037           Train Acc 0.7515 Val Loss 0.5227 Val Acc 0.7328
# Epoch 54/100: Train Loss 0.5036           Train Acc 0.7485 Val Loss 0.5251 Val Acc 0.7334
# Epoch 55/100: Train Loss 0.5024           Train Acc 0.7529 Val Loss 0.5211 Val Acc 0.7356
# Epoch 56/100: Train Loss 0.5014           Train Acc 0.7537 Val Loss 0.5236 Val Acc 0.7332
# Epoch 57/100: Train Loss 0.5011           Train Acc 0.7537 Val Loss 0.5267 Val Acc 0.7298
# Epoch 58/100: Train Loss 0.5011           Train Acc 0.7520 Val Loss 0.5220 Val Acc 0.7348
# Epoch 59/100: Train Loss 0.5014           Train Acc 0.7546 Val Loss 0.5214 Val Acc 0.7356
# Epoch 60/100: Train Loss 0.5008           Train Acc 0.7521 Val Loss 0.5226 Val Acc 0.7328
# Epoch 61/100: Train Loss 0.5001           Train Acc 0.7531 Val Loss 0.5230 Val Acc 0.7366
# Epoch 62/100: Train Loss 0.4991           Train Acc 0.7526 Val Loss 0.5239 Val Acc 0.7322
# Epoch 63/100: Train Loss 0.4992           Train Acc 0.7540 Val Loss 0.5220 Val Acc 0.7372
# Epoch 64/100: Train Loss 0.4985           Train Acc 0.7553 Val Loss 0.5214 Val Acc 0.7334
# Epoch 65/100: Train Loss 0.4984           Train Acc 0.7536 Val Loss 0.5216 Val Acc 0.7336
# Epoch 66/100: Train Loss 0.4984           Train Acc 0.7540 Val Loss 0.5223 Val Acc 0.7340
# Epoch 67/100: Train Loss 0.4974           Train Acc 0.7533 Val Loss 0.5223 Val Acc 0.7366
# Epoch 68/100: Train Loss 0.4977           Train Acc 0.7541 Val Loss 0.5243 Val Acc 0.7350
# Epoch 69/100: Train Loss 0.4967           Train Acc 0.7552 Val Loss 0.5239 Val Acc 0.7348
# Epoch 70/100: Train Loss 0.4971           Train Acc 0.7545 Val Loss 0.5230 Val Acc 0.7384
# Epoch 71/100: Train Loss 0.4963           Train Acc 0.7535 Val Loss 0.5227 Val Acc 0.7366
# Epoch 72/100: Train Loss 0.4964           Train Acc 0.7547 Val Loss 0.5224 Val Acc 0.7360
# Epoch 73/100: Train Loss 0.4957           Train Acc 0.7543 Val Loss 0.5280 Val Acc 0.7326
# Epoch 74/100: Train Loss 0.4952           Train Acc 0.7572 Val Loss 0.5254 Val Acc 0.7314
# Epoch 75/100: Train Loss 0.4952           Train Acc 0.7562 Val Loss 0.5215 Val Acc 0.7384
# Early stopped at Epoch 75

# %%
# 시각화
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'train_loss' : train_losses,
    'val_loss' : val_losses,
    'train_acc' : train_accs,
    'val_acc': val_accs
})

df.plot()
plt.show()

# %%
# 평가
def evaluate_model(model, test_dataloader, criterion):
    model.eval()
    test_loss, test_correct, test_total = 0, 0, 0

    with torch.no_grad():
        for test_inputs, test_labels in test_dataloader:
            output = model(test_inputs)
            loss = criterion(output, test_labels)

            test_loss += loss.item()
            prob = torch.sigmoid(output)
            pred = (prob >= 0.5).float()
            test_correct += (pred == test_labels).sum().item()
            test_total += test_labels.size(0)

    test_loss = test_loss / len(test_dataloader)
    test_acc = test_correct / test_total

    return test_loss, test_acc

test_dataset = TensorDataset(X_test_onehot, y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

test_loss, test_acc = evaluate_model(model, test_dataloader, criterion)
print(f'Test Loss {test_loss} Test Acc {test_acc}')
# Out:
# Test Loss 0.5239396326860805 Test Acc 0.7345

# %% [markdown]
# ## LSTM + Embedding

# %%
# LSTM 모델 생성
class LSTMSentimenticNet(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        
        super().__init__()
        self.embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embedding_dim,
            padding_idx=0
        )
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        _, (hidden, cell) = self.lstm(x)
        output = self.fc(hidden[-1]) # (num_layer, batch_size, hidden_dim)
        return output

embedding_dim = 50
hidden_dim = 16
output_dim = 1

model = LSTMSentimenticNet(vocab_size, embedding_dim, hidden_dim, output_dim)
model
# Out:
# LSTMSentimenticNet(
#   (embedding): Embedding(300, 50, padding_idx=0)
#   (lstm): LSTM(50, 16, batch_first=True)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
# 모델 파라미터 확인
total_params = 0
for name, param in model.named_parameters():
    # print(name, param)
    if param.requires_grad:                 # 미분 가능한 파라미터만 
        param_count = param.numel()         # 모든 가중치 개수
        total_params += param_count         
        print(f'{name:<20} {str(list(param.shape)):<30} {param_count}')

print(f'Total Trainable Parameters : {total_params}')
# Out:
# embedding.weight     [300, 50]                      15000
# lstm.weight_ih_l0    [64, 50]                       3200
# lstm.weight_hh_l0    [64, 16]                       1024
# lstm.bias_ih_l0      [64]                           64
# lstm.bias_hh_l0      [64]                           64
# fc.weight            [1, 16]                        16
# fc.bias              [1]                            1
# Total Trainable Parameters : 19369

# %% [markdown]
# ## LSTM(num_layers) + Embedding

# %%
import torch
import torch.nn as nn

batch_size = 2
seq_len = 3
input_size = 4
hidden_size = 5

x = torch.randn(batch_size, seq_len, input_size)
print('x.shape : ', x.shape)

lstm = nn.LSTM(input_size, hidden_size, batch_first=True, num_layers=2)
output, (hidden, cell) = lstm(x)

print('output : ', output.shape)
print('hidden state : ', hidden.shape)  # (num_layers, batch_size, hidden_size)
print('cell state : ', cell.shape)      # (num_layers, batch_size, hidden_size)
# Out:
# x.shape :  torch.Size([2, 3, 4])
# output :  torch.Size([2, 3, 5])
# hidden state :  torch.Size([2, 2, 5])
# cell state :  torch.Size([2, 2, 5])

# %%
# LSTM 모델 생성
class LSTMSentimenticNet(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers):
        
        super().__init__()
        self.embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embedding_dim,
            padding_idx=0
        )
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=num_layers)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        _, (hidden, cell) = self.lstm(x)
        output = self.fc(hidden[-1]) # (num_layer, batch_size, hidden_dim)
        return output

embedding_dim = 50
hidden_dim = 16
output_dim = 1

model = LSTMSentimenticNet(vocab_size, embedding_dim, hidden_dim, output_dim, num_layers=2)
model
# Out:
# LSTMSentimenticNet(
#   (embedding): Embedding(300, 50, padding_idx=0)
#   (lstm): LSTM(50, 16, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
# 모델 파라미터 확인
total_params = 0
for name, param in model.named_parameters():
    # print(name, param)
    if param.requires_grad:                 # 미분 가능한 파라미터만 
        param_count = param.numel()         # 모든 가중치 개수
        total_params += param_count         
        print(f'{name:<20} {str(list(param.shape)):<30} {param_count}')

print(f'Total Trainable Parameters : {total_params}')
# Out:
# embedding.weight     [300, 50]                      15000
# lstm.weight_ih_l0    [64, 50]                       3200
# lstm.weight_hh_l0    [64, 16]                       1024
# lstm.bias_ih_l0      [64]                           64
# lstm.bias_hh_l0      [64]                           64
# lstm.weight_ih_l1    [64, 16]                       1024
# lstm.weight_hh_l1    [64, 16]                       1024
# lstm.bias_ih_l1      [64]                           64
# lstm.bias_hh_l1      [64]                           64
# fc.weight            [1, 16]                        16
# fc.bias              [1]                            1
# Total Trainable Parameters : 21545

# %% [markdown]
# ### Emebedding + LSTM(bidirectional)
#
# ![](https://d.pr/i/0u69xz+)
#
#
# **Bidirectional LSTM**은 LSTM의 변형 모델로, **양방향으로 데이터를 처리**할 수 있도록 설계된 구조이다. 일반 LSTM이 입력 데이터를 **순방향(forward)** 으로만 처리하는 반면, Bidirectional LSTM은 **순방향**과 **역방향(backward)** 으로 데이터를 동시에 처리하여 더 많은 정보를 학습한다.
#
#
# 1. **양방향 정보 학습**
#    - 순방향 LSTM은 이전 시점의 정보만을 사용하여 다음 시점의 출력을 계산한다.
#    - Bidirectional LSTM은 데이터의 시간적 흐름을 순방향과 역방향으로 모두 고려하여 **이전**과 **이후**의 정보를 동시에 학습한다.
#
# 2. **문맥 정보 강화**
#    - 예를 들어, 텍스트 데이터를 처리할 때 문장의 맥락(Context)을 양방향으로 학습하여 더 정확한 결과를 얻을 수 있다.
#     - 예: "He went to the bank ..."에서 "bank"가 "은행"인지 "강둑"인지 구분하기 위해 이후 단어의 정보를 활용할 수 있다.
#     - Forward LSTM:
#     ```He → went → to → the → bank → to → withdraw → money```
#     - Backward LSTM:
#     ```money → withdraw → to → bank → the → to → went → He```

# %%
import torch
import torch.nn as nn

batch_size = 2
seq_len = 3
input_size = 4
hidden_size = 5

x = torch.randn(batch_size, seq_len, input_size)
print('x.shape : ', x.shape)

lstm = nn.LSTM(input_size, hidden_size, batch_first=True, num_layers=1, bidirectional=True)
output, (hidden, cell) = lstm(x)

print('output : ', output.shape)        # (batch_size, seq_len, hidden_size * 2)
print('hidden state : ', hidden.shape)  # (num_layers * 2, batch_size, hidden_size)
print('cell state : ', cell.shape)      # (num_layers * 2, batch_size, hidden_size)
# Out:
# x.shape :  torch.Size([2, 3, 4])
# output :  torch.Size([2, 3, 10])
# hidden state :  torch.Size([2, 2, 5])
# cell state :  torch.Size([2, 2, 5])

# %%
# LSTM 모델 생성
class LSTMSentimenticNet(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers=1):
        
        super().__init__()
        self.embedding = nn.Embedding(
            num_embeddings=vocab_size,
            embedding_dim=embedding_dim,
            padding_idx=0
        )
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=num_layers, bidirectional=True)
        # 이전 LSTM 출력은 hidden_dim의 2배이다.
        self.fc = nn.Linear(hidden_dim * 2, output_dim)

    def forward(self, x):
        x = self.embedding(x)
        _, (hidden, cell) = self.lstm(x)
        forward_pass = hidden[-2]
        backward_pass = hidden[-1]

        # LSTM 순방향/역방향 결합
        hidden = torch.cat((forward_pass, backward_pass), dim=1)

        output = self.fc(hidden)
        return output

embedding_dim = 50
hidden_dim = 16
output_dim = 1

model = LSTMSentimenticNet(vocab_size, embedding_dim, hidden_dim, output_dim)
model
# Out:
# LSTMSentimenticNet(
#   (embedding): Embedding(300, 50, padding_idx=0)
#   (lstm): LSTM(50, 16, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
# 모델 파라미터 확인
total_params = 0
for name, param in model.named_parameters():
    # print(name, param)
    if param.requires_grad:                 # 미분 가능한 파라미터만 
        param_count = param.numel()         # 모든 가중치 개수
        total_params += param_count         
        print(f'{name:<20} {str(list(param.shape)):<30} {param_count}')

print(f'Total Trainable Parameters : {total_params}')
# Out:
# embedding.weight     [300, 50]                      15000
# lstm.weight_ih_l0    [64, 50]                       3200
# lstm.weight_hh_l0    [64, 16]                       1024
# lstm.bias_ih_l0      [64]                           64
# lstm.bias_hh_l0      [64]                           64
# lstm.weight_ih_l0_reverse [64, 50]                       3200
# lstm.weight_hh_l0_reverse [64, 16]                       1024
# lstm.bias_ih_l0_reverse [64]                           64
# lstm.bias_hh_l0_reverse [64]                           64
# fc.weight            [1, 32]                        32
# fc.bias              [1]                            1
# Total Trainable Parameters : 23737

# %%
# one-hot encoding 에서 Embedding 으로 변경하여 입력 데이터 재가공
X_train = torch.tensor(X_train, dtype=torch.long)
X_test = torch.tensor(X_test, dtype=torch.long)

y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([25000, 100]) torch.Size([25000, 1])
# torch.Size([10000, 100]) torch.Size([10000, 1])
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_10692\295090378.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_10692\295090378.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
# 학습/검증/평가 데이터 준비
from torch.utils.data import random_split, DataLoader, TensorDataset

batch_size = 64
train_size = int(len(X_train) * 0.8)
val_size = len(X_train) - train_size

train_dataset, val_dataset = random_split(TensorDataset(X_train, y_train), [train_size, val_size])
test_dataset = TensorDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
from torch.optim import Adam

# 손실 함수
criterion = nn.BCEWithLogitsLoss()
# 옵티마이저
optimizer = Adam(model.parameters(), lr=0.0001)

epochs = 100

# 시각화를 위한 기록
train_losses, val_losses, train_accs, val_accs = [], [], [], []

# 조기 종료 관련
early_stopping_patience = 20
best_val_loss = float('inf')
early_stopping_counter = 0

for epoch in range(epochs):
    total_loss, correct, total = 0, 0, 0

    # 학습
    model.train()
    for inputs, labels in train_dataloader:
        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        # 배치 로그
        total_loss += loss.item()
        prob = torch.sigmoid(output)
        pred = (prob >= 0.5).float()
        correct += (pred == labels).sum().item()
        total += labels.size(0)
    
    # 에폭 로그
    train_loss = total_loss / len(train_dataloader)
    train_losses.append(train_loss)
    train_acc = correct / total
    train_accs.append(train_acc)

    # 검증
    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for val_inputs, val_labels in val_dataloader:

            output = model(val_inputs)
            loss = criterion(output, val_labels)

            # 배치 로그
            val_loss += loss.item()
            prob = torch.sigmoid(output)
            pred = (prob >= 0.5).float()
            val_correct += (pred == val_labels).sum().item()
            val_total += val_labels.size(0)

    # 에폭 로그
    val_loss = val_loss / len(val_dataloader)
    val_losses.append(val_loss)
    val_acc = val_correct / val_total
    val_accs.append(val_acc)

    print(f'Epoch {epoch + 1}/{epochs}: Train Loss {train_loss:.4f} \
          Train Acc {train_acc:.4f} Val Loss {val_loss:.4f} Val Acc {val_acc:.4f}')
    
    # 조기종료
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early stopped at Epoch {epoch + 1}')
            break
# Out:
# Epoch 1/100: Train Loss 0.6939           Train Acc 0.5018 Val Loss 0.6928 Val Acc 0.5194
# Epoch 2/100: Train Loss 0.6927           Train Acc 0.5170 Val Loss 0.6920 Val Acc 0.5312
# Epoch 3/100: Train Loss 0.6915           Train Acc 0.5260 Val Loss 0.6915 Val Acc 0.5338
# Epoch 4/100: Train Loss 0.6901           Train Acc 0.5392 Val Loss 0.6905 Val Acc 0.5376
# Epoch 5/100: Train Loss 0.6881           Train Acc 0.5461 Val Loss 0.6882 Val Acc 0.5458
# Epoch 6/100: Train Loss 0.6855           Train Acc 0.5597 Val Loss 0.6859 Val Acc 0.5536
# Epoch 7/100: Train Loss 0.6814           Train Acc 0.5693 Val Loss 0.6808 Val Acc 0.5690
# Epoch 8/100: Train Loss 0.6757           Train Acc 0.5815 Val Loss 0.6787 Val Acc 0.5684
# Epoch 9/100: Train Loss 0.6696           Train Acc 0.5930 Val Loss 0.6724 Val Acc 0.5876
# Epoch 10/100: Train Loss 0.6631           Train Acc 0.6046 Val Loss 0.6689 Val Acc 0.5970
# Epoch 11/100: Train Loss 0.6579           Train Acc 0.6129 Val Loss 0.6634 Val Acc 0.6020
# Epoch 12/100: Train Loss 0.6523           Train Acc 0.6204 Val Loss 0.6600 Val Acc 0.6098
# Epoch 13/100: Train Loss 0.6464           Train Acc 0.6276 Val Loss 0.6562 Val Acc 0.6150
# Epoch 14/100: Train Loss 0.6392           Train Acc 0.6377 Val Loss 0.6499 Val Acc 0.6224
# Epoch 15/100: Train Loss 0.6328           Train Acc 0.6434 Val Loss 0.6464 Val Acc 0.6250
# Epoch 16/100: Train Loss 0.6258           Train Acc 0.6521 Val Loss 0.6407 Val Acc 0.6346
# Epoch 17/100: Train Loss 0.6208           Train Acc 0.6590 Val Loss 0.6349 Val Acc 0.6390
# Epoch 18/100: Train Loss 0.6140           Train Acc 0.6649 Val Loss 0.6372 Val Acc 0.6444
# Epoch 19/100: Train Loss 0.6095           Train Acc 0.6697 Val Loss 0.6294 Val Acc 0.6496
# Epoch 20/100: Train Loss 0.6048           Train Acc 0.6740 Val Loss 0.6265 Val Acc 0.6558
# Epoch 21/100: Train Loss 0.6020           Train Acc 0.6746 Val Loss 0.6274 Val Acc 0.6506
# Epoch 22/100: Train Loss 0.5961           Train Acc 0.6831 Val Loss 0.6199 Val Acc 0.6592
# Epoch 23/100: Train Loss 0.5924           Train Acc 0.6851 Val Loss 0.6172 Val Acc 0.6654
# Epoch 24/100: Train Loss 0.5890           Train Acc 0.6879 Val Loss 0.6160 Val Acc 0.6724
# Epoch 25/100: Train Loss 0.5844           Train Acc 0.6926 Val Loss 0.6134 Val Acc 0.6714
# Epoch 26/100: Train Loss 0.5801           Train Acc 0.6973 Val Loss 0.6150 Val Acc 0.6738
# Epoch 27/100: Train Loss 0.5765           Train Acc 0.7016 Val Loss 0.6120 Val Acc 0.6784
# Epoch 28/100: Train Loss 0.5735           Train Acc 0.7029 Val Loss 0.6056 Val Acc 0.6832
# Epoch 29/100: Train Loss 0.5696           Train Acc 0.7062 Val Loss 0.6031 Val Acc 0.6848
# Epoch 30/100: Train Loss 0.5669           Train Acc 0.7073 Val Loss 0.6006 Val Acc 0.6870
# Epoch 31/100: Train Loss 0.5631           Train Acc 0.7118 Val Loss 0.6011 Val Acc 0.6896
# Epoch 32/100: Train Loss 0.5607           Train Acc 0.7154 Val Loss 0.5988 Val Acc 0.6900
# Epoch 33/100: Train Loss 0.5582           Train Acc 0.7166 Val Loss 0.5955 Val Acc 0.6916
# Epoch 34/100: Train Loss 0.5559           Train Acc 0.7161 Val Loss 0.5962 Val Acc 0.6896
# Epoch 35/100: Train Loss 0.5506           Train Acc 0.7218 Val Loss 0.5956 Val Acc 0.6922
# Epoch 36/100: Train Loss 0.5491           Train Acc 0.7210 Val Loss 0.5940 Val Acc 0.6944
# Epoch 37/100: Train Loss 0.5458           Train Acc 0.7271 Val Loss 0.5881 Val Acc 0.6976
# Epoch 38/100: Train Loss 0.5443           Train Acc 0.7287 Val Loss 0.5883 Val Acc 0.6992
# Epoch 39/100: Train Loss 0.5401           Train Acc 0.7291 Val Loss 0.5888 Val Acc 0.7026
# Epoch 40/100: Train Loss 0.5423           Train Acc 0.7299 Val Loss 0.5851 Val Acc 0.6990
# Epoch 41/100: Train Loss 0.5362           Train Acc 0.7321 Val Loss 0.5834 Val Acc 0.7018
# Epoch 42/100: Train Loss 0.5362           Train Acc 0.7304 Val Loss 0.5851 Val Acc 0.7010
# Epoch 43/100: Train Loss 0.5319           Train Acc 0.7370 Val Loss 0.5851 Val Acc 0.6980
# Epoch 44/100: Train Loss 0.5296           Train Acc 0.7379 Val Loss 0.5817 Val Acc 0.7030
# Epoch 45/100: Train Loss 0.5304           Train Acc 0.7391 Val Loss 0.5815 Val Acc 0.7018
# Epoch 46/100: Train Loss 0.5261           Train Acc 0.7396 Val Loss 0.5826 Val Acc 0.7006
# Epoch 47/100: Train Loss 0.5286           Train Acc 0.7402 Val Loss 0.5781 Val Acc 0.6982
# Epoch 48/100: Train Loss 0.5248           Train Acc 0.7409 Val Loss 0.5817 Val Acc 0.7038
# Epoch 49/100: Train Loss 0.5245           Train Acc 0.7396 Val Loss 0.5788 Val Acc 0.7048
# Epoch 50/100: Train Loss 0.5199           Train Acc 0.7447 Val Loss 0.5798 Val Acc 0.7048
# Epoch 51/100: Train Loss 0.5187           Train Acc 0.7453 Val Loss 0.5794 Val Acc 0.7038
# Epoch 52/100: Train Loss 0.5165           Train Acc 0.7458 Val Loss 0.5776 Val Acc 0.7070
# Epoch 53/100: Train Loss 0.5138           Train Acc 0.7473 Val Loss 0.5789 Val Acc 0.7080
# Epoch 54/100: Train Loss 0.5164           Train Acc 0.7443 Val Loss 0.5755 Val Acc 0.7076
# Epoch 55/100: Train Loss 0.5124           Train Acc 0.7497 Val Loss 0.5742 Val Acc 0.7076
# Epoch 56/100: Train Loss 0.5113           Train Acc 0.7501 Val Loss 0.5775 Val Acc 0.7088
# Epoch 57/100: Train Loss 0.5080           Train Acc 0.7532 Val Loss 0.5744 Val Acc 0.7114
# Epoch 58/100: Train Loss 0.5088           Train Acc 0.7487 Val Loss 0.5747 Val Acc 0.7114
# Epoch 59/100: Train Loss 0.5064           Train Acc 0.7522 Val Loss 0.5779 Val Acc 0.7064
# Epoch 60/100: Train Loss 0.5058           Train Acc 0.7529 Val Loss 0.5717 Val Acc 0.7092
# Epoch 61/100: Train Loss 0.5041           Train Acc 0.7545 Val Loss 0.5726 Val Acc 0.7118
# Epoch 62/100: Train Loss 0.5064           Train Acc 0.7533 Val Loss 0.5744 Val Acc 0.7080
# Epoch 63/100: Train Loss 0.5023           Train Acc 0.7560 Val Loss 0.5723 Val Acc 0.7116
# Epoch 64/100: Train Loss 0.5006           Train Acc 0.7571 Val Loss 0.5720 Val Acc 0.7120
# Epoch 65/100: Train Loss 0.4993           Train Acc 0.7568 Val Loss 0.5721 Val Acc 0.7116
# Epoch 66/100: Train Loss 0.5017           Train Acc 0.7543 Val Loss 0.5746 Val Acc 0.7108
# Epoch 67/100: Train Loss 0.4977           Train Acc 0.7605 Val Loss 0.5719 Val Acc 0.7122
# Epoch 68/100: Train Loss 0.4974           Train Acc 0.7589 Val Loss 0.5761 Val Acc 0.6978
# Epoch 69/100: Train Loss 0.5020           Train Acc 0.7560 Val Loss 0.5683 Val Acc 0.7110
# Epoch 70/100: Train Loss 0.4920           Train Acc 0.7620 Val Loss 0.5697 Val Acc 0.7112
# Epoch 71/100: Train Loss 0.4964           Train Acc 0.7592 Val Loss 0.5667 Val Acc 0.7124
# Epoch 72/100: Train Loss 0.4972           Train Acc 0.7599 Val Loss 0.5741 Val Acc 0.7154
# Epoch 73/100: Train Loss 0.4947           Train Acc 0.7598 Val Loss 0.5743 Val Acc 0.7128
# Epoch 74/100: Train Loss 0.4897           Train Acc 0.7643 Val Loss 0.5722 Val Acc 0.7144
# Epoch 75/100: Train Loss 0.4884           Train Acc 0.7649 Val Loss 0.5728 Val Acc 0.7134
# Epoch 76/100: Train Loss 0.5064           Train Acc 0.7543 Val Loss 0.5769 Val Acc 0.7106
# Epoch 77/100: Train Loss 0.4908           Train Acc 0.7652 Val Loss 0.5708 Val Acc 0.7156
# Epoch 78/100: Train Loss 0.4865           Train Acc 0.7680 Val Loss 0.5721 Val Acc 0.7148
# Epoch 79/100: Train Loss 0.4854           Train Acc 0.7670 Val Loss 0.5695 Val Acc 0.7154
# Epoch 80/100: Train Loss 0.4874           Train Acc 0.7672 Val Loss 0.5683 Val Acc 0.7180
# Epoch 81/100: Train Loss 0.4837           Train Acc 0.7701 Val Loss 0.5677 Val Acc 0.7154
# Epoch 82/100: Train Loss 0.4830           Train Acc 0.7673 Val Loss 0.5707 Val Acc 0.7176
# Epoch 83/100: Train Loss 0.4796           Train Acc 0.7705 Val Loss 0.5666 Val Acc 0.7136
# Epoch 84/100: Train Loss 0.4789           Train Acc 0.7712 Val Loss 0.5714 Val Acc 0.7160
# Epoch 85/100: Train Loss 0.4825           Train Acc 0.7703 Val Loss 0.5698 Val Acc 0.7146
# Epoch 86/100: Train Loss 0.4780           Train Acc 0.7706 Val Loss 0.5702 Val Acc 0.7154
# Epoch 87/100: Train Loss 0.4761           Train Acc 0.7725 Val Loss 0.5694 Val Acc 0.7148
# Epoch 88/100: Train Loss 0.4772           Train Acc 0.7708 Val Loss 0.5685 Val Acc 0.7154
# Epoch 89/100: Train Loss 0.4788           Train Acc 0.7731 Val Loss 0.5721 Val Acc 0.7174
# Epoch 90/100: Train Loss 0.4752           Train Acc 0.7733 Val Loss 0.5675 Val Acc 0.7144
# Epoch 91/100: Train Loss 0.4741           Train Acc 0.7748 Val Loss 0.5690 Val Acc 0.7176
# Epoch 92/100: Train Loss 0.4720           Train Acc 0.7756 Val Loss 0.5670 Val Acc 0.7158
# Epoch 93/100: Train Loss 0.4709           Train Acc 0.7759 Val Loss 0.5714 Val Acc 0.7204
# Epoch 94/100: Train Loss 0.4745           Train Acc 0.7737 Val Loss 0.5706 Val Acc 0.7196
# Epoch 95/100: Train Loss 0.4697           Train Acc 0.7755 Val Loss 0.5674 Val Acc 0.7142
# Epoch 96/100: Train Loss 0.4679           Train Acc 0.7780 Val Loss 0.5684 Val Acc 0.7202
# Epoch 97/100: Train Loss 0.4701           Train Acc 0.7767 Val Loss 0.5653 Val Acc 0.7200
# Epoch 98/100: Train Loss 0.4671           Train Acc 0.7788 Val Loss 0.5687 Val Acc 0.7202
# Epoch 99/100: Train Loss 0.4680           Train Acc 0.7801 Val Loss 0.5693 Val Acc 0.7160
# Epoch 100/100: Train Loss 0.4644           Train Acc 0.7806 Val Loss 0.5735 Val Acc 0.7152

# %%
# 시각화
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'train_loss' : train_losses,
    'val_loss' : val_losses,
    'train_acc' : train_accs,
    'val_acc': val_accs
})

df.plot()
plt.show()

# %%
# 평가
def evaluate_model(model, test_dataloader, criterion):
    model.eval()
    test_loss, test_correct, test_total = 0, 0, 0

    with torch.no_grad():
        for test_inputs, test_labels in test_dataloader:
            output = model(test_inputs)
            loss = criterion(output, test_labels)

            test_loss += loss.item()
            prob = torch.sigmoid(output)
            pred = (prob >= 0.5).float()
            test_correct += (pred == test_labels).sum().item()
            test_total += test_labels.size(0)

    test_loss = test_loss / len(test_dataloader)
    test_acc = test_correct / test_total

    return test_loss, test_acc

test_dataset = TensorDataset(X_test, y_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

test_loss, test_acc = evaluate_model(model, test_dataloader, criterion)
print(f'Test Loss {test_loss} Test Acc {test_acc}')
# Out:
# Test Loss 0.5716978704473775 Test Acc 0.7137
